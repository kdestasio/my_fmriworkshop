# %%
from nilearn.plotting import plot_roi, plot_stat_map, plot_glass_brain
# %matplotlib inline

# %%
plot_roi?

# %%
plot_roi("/tmp/sub-10159_T1w_brain_mask.nii.gz", 
         "/Users/kristadestasio/Desktop/data/sub-10159/anat/sub-10159_T1w.nii.gz", 
         display_mode='y')

# %%
from glob import glob
for map_file in glob("/Users/kristadestasio/Desktop/data/derivatives/pretend_lv2/lv2.gfeat/cope*.feat/thresh_zstat1.nii.gz")[:2]:
    plot_stat_map(map_file, cut_coords=(10, 10, 10))

# %%
plot_stat_map?

# %%
from glob import glob
for map_file in glob("/Users/kristadestasio/Desktop/data/derivatives/pretend_lv2/lv2.gfeat/cope*.feat/thresh_zstat1.nii.gz")[:2]:
    plot_glass_brain(map_file)
